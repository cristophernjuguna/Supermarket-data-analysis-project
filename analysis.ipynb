# %%
import pandas as pd

# %%
import os

# %%
from sqlalchemy import create_engine

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
db_url = os.getenv("DATABASE_URL")

# %%
sql_query = """
select* from
purchase_data pd
left join transaction_data td 
on pd."LYLTY_CARD_NBR"=td."LYLTY_CARD_NBR";
"""

# %%
data_df = pd.read_sql(sql_query,con=db_url)

# %%
print(data_df.columns)
# Out:
# Index(['LYLTY_CARD_NBR', 'LIFESTAGE', 'PREMIUM_CUSTOMER', 'DATE', 'STORE_NBR',
#        'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR', 'PROD_NAME', 'PROD_QTY',
#        'TOT_SALES'],
#       dtype='object')

# %%
data_df['DATE'] = pd.to_datetime(data_df['DATE'], errors='coerce')

# %%
engine = create_engine(db_url)

# %%
transaction_data = data_df
transaction_data.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0            2373  MIDAGE SINGLES/COUPLES           Budget 2018-08-17
# 1            4074  MIDAGE SINGLES/COUPLES           Budget 2019-05-19
# 2            4149  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 3            4196  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 4            7150  MIDAGE SINGLES/COUPLES           Budget 2018-08-18
#
#    STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0          2            2373     974        69
# 1          4            4074    2982        57
# 2          4            4149    3333        16
# 3          4            4196    3539        24
# 4          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 1  Old El Paso Salsa   Dip Tomato Mild 300g         1        5.1
# 2  Smiths Crinkle Chips Salt & Vinegar 330g         1        5.7
# 3     Grain Waves         Sweet Chilli 210g         1        3.6
# 4     Grain Waves Sour    Cream&Chives 210G         2        7.2

# %%
transaction_data.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0            2373  MIDAGE SINGLES/COUPLES           Budget 2018-08-17
# 1            4074  MIDAGE SINGLES/COUPLES           Budget 2019-05-19
# 2            4149  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 3            4196  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 4            7150  MIDAGE SINGLES/COUPLES           Budget 2018-08-18
#
#    STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0          2            2373     974        69
# 1          4            4074    2982        57
# 2          4            4149    3333        16
# 3          4            4196    3539        24
# 4          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 1  Old El Paso Salsa   Dip Tomato Mild 300g         1        5.1
# 2  Smiths Crinkle Chips Salt & Vinegar 330g         1        5.7
# 3     Grain Waves         Sweet Chilli 210g         1        3.6
# 4     Grain Waves Sour    Cream&Chives 210G         2        7.2

# %%
data_df.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0            2373  MIDAGE SINGLES/COUPLES           Budget 2018-08-17
# 1            4074  MIDAGE SINGLES/COUPLES           Budget 2019-05-19
# 2            4149  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 3            4196  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 4            7150  MIDAGE SINGLES/COUPLES           Budget 2018-08-18
#
#    STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0          2            2373     974        69
# 1          4            4074    2982        57
# 2          4            4149    3333        16
# 3          4            4196    3539        24
# 4          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 1  Old El Paso Salsa   Dip Tomato Mild 300g         1        5.1
# 2  Smiths Crinkle Chips Salt & Vinegar 330g         1        5.7
# 3     Grain Waves         Sweet Chilli 210g         1        3.6
# 4     Grain Waves Sour    Cream&Chives 210G         2        7.2

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %%
load_dotenv()
con = os.getenv("DATABASE_URL")

# %%
engine = create_engine(con)

# %%
purchase_data_query = '''
select * from
purchase_data pd;
'''
purchase_data = pd.read_sql(purchase_data_query, con=engine)

# %%
purchase_data.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
joined_query = '''
select * from
purchase_data pd
left join transaction_data td 
on pd."LYLTY_CARD_NBR"=td."LYLTY_CARD_NBR";
'''

# %%
data = pd.read_sql(joined_query, con=engine)

# %%
data.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER       DATE  \
# 0            2373  MIDAGE SINGLES/COUPLES           Budget 2018-08-17
# 1            4074  MIDAGE SINGLES/COUPLES           Budget 2019-05-19
# 2            4149  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 3            4196  MIDAGE SINGLES/COUPLES           Budget 2019-05-16
# 4            7150  MIDAGE SINGLES/COUPLES           Budget 2018-08-18
#
#    STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0          2            2373     974        69
# 1          4            4074    2982        57
# 2          4            4149    3333        16
# 3          4            4196    3539        24
# 4          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 1  Old El Paso Salsa   Dip Tomato Mild 300g         1        5.1
# 2  Smiths Crinkle Chips Salt & Vinegar 330g         1        5.7
# 3     Grain Waves         Sweet Chilli 210g         1        3.6
# 4     Grain Waves Sour    Cream&Chives 210G         2        7.2

# %%
data.isna().sum()
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# DATE                0
# STORE_NBR           0
# LYLTY_CARD_NBR      0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# dtype: int64

# %%
data.shape
# Out:
# (529672, 11)

# %%
data = data.drop_duplicates

# %%
purchase_data_query = '''
select * from transaction_data;
'''
transaction_data = pd.read_sql(purchase_data_query, con=engine)

# %%
merged_df = transaction_data.merge(purchase_data, on='LYLTY_CARD_NBR', how='left')

# %%
merged_df.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
#
#                 LIFESTAGE PREMIUM_CUSTOMER
# 0   YOUNG SINGLES/COUPLES          Premium
# 1  MIDAGE SINGLES/COUPLES           Budget
# 2  MIDAGE SINGLES/COUPLES           Budget
# 3  MIDAGE SINGLES/COUPLES           Budget
# 4  MIDAGE SINGLES/COUPLES           Budget

# %% [markdown]
# ### objectives
# 1. top 10 most purchased brand
# 2. total sales by customer life stage
# 3. average spend per customer category

# %% [markdown]
# ### Top 10 brands

# %%
top_brands = (merged_df.groupby('PROD_NAME')['PROD_QTY'].sum().sort_values(ascending=False).head(10))

# %%
top_brands
# Out:
# PROD_NAME
# Dorito Corn Chp     Supreme 380g            13018
# Kettle Mozzarella   Basil & Pesto 175g      12762
# Kettle Tortilla ChpsHny&Jlpno Chili 150g    12618
# Cobs Popd Sea Salt  Chips 110g              12554
# Cobs Popd Swt/Chlli &Sr/Cream Chips 110g    12512
# Tostitos Splash Of  Lime 175g               12468
# Tyrrells Crisps     Ched & Chives 165g      12454
# Kettle 135g Swt Pot Sea Salt                12424
# Infuzions Thai SweetChili PotatoMix 110g    12412
# Thins Potato Chips  Hot & Spicy 175g        12370
# Name: PROD_QTY, dtype: int64

# %% [markdown]
# ### total sales by customer life stage

# %%
sales_by_lifestage = (merged_df.groupby('LIFESTAGE')['TOT_SALES'].sum().sort_values(ascending=False))

# %%
sales_by_lifestage
# Out:
# LIFESTAGE
# OLDER SINGLES/COUPLES     804853.5
# RETIREES                  732941.8
# OLDER FAMILIES            707534.4
# YOUNG FAMILIES            632320.2
# YOUNG SINGLES/COUPLES     520810.6
# MIDAGE SINGLES/COUPLES    369502.6
# NEW FAMILIES              100866.9
# Name: TOT_SALES, dtype: float64

# %% [markdown]
# ### average spend per customer category

# %%
avg_spend_category = (merged_df.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].mean())

# %%
avg_spend_category
# Out:
# PREMIUM_CUSTOMER
# Budget        7.258838
# Mainstream    7.361106
# Premium       7.281556
# Name: TOT_SALES, dtype: float64

# %% [markdown]
# ### Monthly sales trend

# %%
merged_df['YEAR']=merged_df['DATE'].dt.year

# %%
merged_df['MONTH']=merged_df['DATE'].dt.month

# %%
merged_df['MONTH_NAME']=merged_df['DATE'].dt.month_name()

# %%
merged_df.head()
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 2018-10-17          1            1000       1         5
# 1 2019-05-14          1            1307     348        66
# 2 2019-05-20          1            1343     383        61
# 3 2018-08-17          2            2373     974        69
# 4 2018-08-18          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
#
#                 LIFESTAGE PREMIUM_CUSTOMER  YEAR  MONTH MONTH_NAME
# 0   YOUNG SINGLES/COUPLES          Premium  2018     10    October
# 1  MIDAGE SINGLES/COUPLES           Budget  2019      5        May
# 2  MIDAGE SINGLES/COUPLES           Budget  2019      5        May
# 3  MIDAGE SINGLES/COUPLES           Budget  2018      8     August
# 4  MIDAGE SINGLES/COUPLES           Budget  2018      8     August

# %%
monthly_sales=(merged_df.groupby(['YEAR', 'MONTH_NAME'])['TOT_SALES'].sum().reset_index().sort_values(['YEAR', 'MONTH_NAME']))

# %%
monthly_sales
# Out:
#     YEAR MONTH_NAME  TOT_SALES
# 0   2018     August   317462.1
# 1   2018   December   335826.8
# 2   2018       July   330550.6
# 3   2018   November   320467.4
# 4   2018    October   328831.4
# 5   2018  September   321044.0
# 6   2019      April   319690.2
# 7   2019   February   301330.0
# 8   2019    January   325284.6
# 9   2019       June   321077.2
# 10  2019      March   332530.4
# 11  2019        May   314735.3

# %%
yearly_sales=(merged_df.groupby('YEAR')['TOT_SALES'].sum().sort_values(ascending=False))

# %%
yearly_sales
# Out:
# YEAR
# 2018    1954182.3
# 2019    1914647.7
# Name: TOT_SALES, dtype: float64

# %% [markdown]
# ### store performance

# %%
store_sales = (merged_df.groupby('STORE_NBR')['TOT_SALES'].sum().sort_values(ascending=False).head(10))

# %%
store_sales
# Out:
# STORE_NBR
# 226    37810.9
# 88     32666.5
# 165    31947.5
# 40     31119.0
# 237    31079.0
# 58     30502.9
# 199    29594.0
# 4      29295.3
# 203    29103.2
# 26     28938.6
# Name: TOT_SALES, dtype: float64

# %%
product_sales = (merged_df.groupby('PROD_NAME')['TOT_SALES'].sum().sort_values(ascending=False).head(10))

# %%
product_sales
# Out:
# PROD_NAME
# Dorito Corn Chp     Supreme 380g            80704.0
# Smiths Crnkle Chip  Orgnl Big Bag 380g      72735.2
# Smiths Crinkle Chips Salt & Vinegar 330g    69608.4
# Kettle Mozzarella   Basil & Pesto 175g      68914.8
# Smiths Crinkle      Original 330g           68605.2
# Cheezels Cheese 330g                        68593.8
# Doritos Cheese      Supreme 330g            66781.2
# Kettle Sweet Chilli And Sour Cream 175g     66063.6
# Kettle Original 175g                        65480.4
# Kettle Sea Salt     And Vinegar 175g        65178.0
# Name: TOT_SALES, dtype: float64

# %% [markdown]
# ### Customer behaviour

# %% [markdown]
# ### which life stage buys the largest quantity

# %%
merged_df.columns
# Out:
# Index(['DATE', 'STORE_NBR', 'LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR',
#        'PROD_NAME', 'PROD_QTY', 'TOT_SALES', 'LIFESTAGE', 'PREMIUM_CUSTOMER',
#        'YEAR', 'MONTH', 'MONTH_NAME'],
#       dtype='object')

# %%
quantity_by_lifestage = (merged_df.groupby('LIFESTAGE')['PROD_QTY'].sum().sort_values(ascending=False))

# %%
quantity_by_lifestage
# Out:
# LIFESTAGE
# OLDER SINGLES/COUPLES     208406
# OLDER FAMILIES            189984
# RETIREES                  188332
# YOUNG FAMILIES            169122
# YOUNG SINGLES/COUPLES     133268
# MIDAGE SINGLES/COUPLES     95442
# NEW FAMILIES               25694
# Name: PROD_QTY, dtype: int64

# %% [markdown]
# ### which premium tier spends the most overall?

# %%
premium_spend = (merged_df.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].sum().sort_values(ascending=False))

# %%
premium_spend
# Out:
# PREMIUM_CUSTOMER
# Mainstream    1501489.0
# Budget        1352423.1
# Premium       1014917.9
# Name: TOT_SALES, dtype: float64
